# %% [markdown]
# # Diff of the functions from Solution 1

# %% [markdown]
# ### intersect()
#
# Becomes an inner function of `find_peaks()`
#
# ### split_image()
# <table style="margin-left:0px;">
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;"></code></td><td style="text-align:left;"><code style="background-color: #c6f7d3;">@python_app(executors=['local_tpex'])</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">def split_image(imname: str) -> tuple:</code></td><td style="text-align:left;"><code style="background-color: #f5f5f5;">def split_image(inputs: list =[]) -> tuple:</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;"></code></td><td style="text-align:left;"><code style="background-color: #c6f7d3;">    import skimage.io</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;"></code></td><td style="text-align:left;"><code style="background-color: #c6f7d3;">    import numpy as np</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f7e9a8;">    myimage = skimage.io.imread(imname).astype(np.uint8)</code></td><td style="text-align:left;"><code style="background-color: #f7e9a8;">    myimage = skimage.io.imread(inputs[0].filepath).astype(np.uint8)</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;"></code></td><td style="text-align:left;"><code style="background-color: #f5f5f5;"></code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">    r = myimage[:,:,0]</code></td><td style="text-align:left;"><code style="background-color: #c8cbce;">    r = myimage[:, :, 0]</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">    g = myimage[:,:,1]</code></td><td style="text-align:left;"><code style="background-color: #f5f5f5;">    g = myimage[:, :, 1]</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">    b = myimage[:,:,2]</code></td><td style="text-align:left;"><code style="background-color: #c8cbce;">    b = myimage[:, :, 2]</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">    return r, g, b</code></td><td style="text-align:left;"><code style="background-color: #f5f5f5;">    return r, g, b</code></td></tr>
# </table>
#
#
# ### twoD_Gaussian()
#
# Becomes an inner function of both `make_image()` and `make_fits()`
#
# ### find_peaks()
# <table style="margin-left:0px;">
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c6f7d3;">@python_app(executors=['local_tpex'])</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">def find_peaks(in_img: np.ndarray, min_dist: int = 10) -> list:</code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;">def find_peaks(in_img: np.ndarray, min_dist: int = 10) -> list:</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c6f7d3;">    import math</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c6f7d3;">    import numpy as np</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c6f7d3;">    import skimage.feature as feature</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">    bias = 0.</code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;">    bias = 0.</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">    limcut = 0.6</code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;">    limcut = 0.6</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;"></code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c6f7d3;">    def intersect(c1: list, c2: list, radius: float) -> bool:</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c6f7d3;">        d = math.sqrt((c1[0] - c2[0]) * (c1[0] - c2[0]) +</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c6f7d3;">                      (c1[1] - c2[1]) * (c1[1] - c2[1]))
# </code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c6f7d3;">        if d < (2 * radius * .9):</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c6f7d3;">            return True</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c6f7d3;">        return False</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">    img = in_img.astype(np.float32)/255.</code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;">    img = in_img.astype(np.float32)/255.</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">    img[img < bias] = bias</code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;">    img[img < bias] = bias</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">    limg = np.arcsinh(img)</code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;">    limg = np.arcsinh(img)</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">    limg = limg / limg.max()</code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;">    limg = limg / limg.max()</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">    limg[limg < limcut] = 0.</code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;">    limg[limg < limcut] = 0.</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;"></code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">    peaks = feature.peak_local_max(limg, min_distance=min_dist, threshold_abs=limcut)</code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;">    peaks = feature.peak_local_max(limg, min_distance=min_dist, threshold_abs=limcut)</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;"></code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">    skip = []</code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;">    skip = []</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">    pksize = len(peaks)</code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;">    pksize = len(peaks)</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">    peaklist = []</code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;">    peaklist = []</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">    for i in range(pksize):</code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;">    for i in range(pksize):</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">        if i in skip:</code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;">        if i in skip:</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">            continue</code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;">            continue</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">        item = []</code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;">        item = []</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">        for j in range(i + 1, pksize):</code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;">        for j in range(i + 1, pksize):</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">            if j in skip:</code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;">            if j in skip:</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">                continue</code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;">                continue</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">            if intersect(peaks[i], peaks[j], min_dist):</code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;">            if intersect(peaks[i], peaks[j], min_dist):</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">                skip.append(j)</code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;">                skip.append(j)</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">                skip.append(i)</code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;">                skip.append(i)</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">                item.append(peaks[j])</code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;">                item.append(peaks[j])</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">        if item:</code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;">        if item:</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">            item.append(peaks[i])</code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;">            item.append(peaks[i])</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">            peaklist.append(item)</code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;">            peaklist.append(item)</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">        else :</code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;">        else :</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">            peaklist.append([peaks[i]])</code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;">            peaklist.append([peaks[i]])</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;"></code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">    return peaklist</code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;">    return peaklist</code></td></tr>
#
# </table>
#
# ### make_fits()
#
# <table style="margin-left:0px;">
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c6f7d3;">@python_app(executors=['local_tpex'])</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f7e9a8;">def make_fits(images: list, centers: list, offsets: list) -> list:</code></td>
#         <td style="text-align:left;"><code style="background-color: #f7e9a8;">def make_fits(input_data: tuple) -> pd.DataFrame:</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c6f7d3;">    import pandas as pd</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c6f7d3;">    import numpy as np</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c6f7d3;">    import scipy.optimize as opt</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c6f7d3;"></code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c6f7d3;">    def twoD_Gaussian(point: tuple, amplitude: float, xo: float, yo: float, sigma_x: float, sigma_y: float,</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c6f7d3;">                      theta: float):</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c6f7d3;">        (x, y) = point</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c6f7d3;">        xo = float(xo)</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c6f7d3;">        yo = float(yo)</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c6f7d3;">        a = (np.cos(theta) ** 2) / (2 * sigma_x ** 2) + (np.sin(theta) ** 2) / (2 * sigma_y ** 2)</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c6f7d3;">        b = -(np.sin(2 * theta)) / (4 * sigma_x ** 2) + (np.sin(2 * theta)) / (4 * sigma_y ** 2)</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c6f7d3;">        c = (np.sin(theta) ** 2) / (2 * sigma_x ** 2) + (np.cos(theta) ** 2) / (2 * sigma_y ** 2)</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c6f7d3;">        gaussian = amplitude * np.exp(-(a * ((x - xo) ** 2) + 2 * b * (x - xo) * (y - yo) + c * ((y - yo) ** 2)))</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c6f7d3;">        return gaussian.ravel()</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c6f7d3;"></code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">    fit_params = pd.DataFrame({'Amplitude': pd.Series(dtype=float),</code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;">    fit_params = pd.DataFrame({'Amplitude': pd.Series(dtype=float),</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">                               'Xo': pd.Series(dtype=float),</code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;">                               'Xo': pd.Series(dtype=float),</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">                               'Yo': pd.Series(dtype=float),</code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;">                               'Yo': pd.Series(dtype=float),</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">                               'sigmaX': pd.Series(dtype=float),</code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;">                               'sigmaX': pd.Series(dtype=float),</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">                               'sigmaY': pd.Series(dtype=float),</code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;">                               'sigmaY': pd.Series(dtype=float),</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">                               'theta': pd.Series(dtype=float)})</code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;">                               'theta': pd.Series(dtype=float)})</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;"></code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c6f7d3;">    (images, centers, offsets) = input_data</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">    for i in range(len(images)):</code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;">    for i in range(len(images)):</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">        try:</code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;">        try:</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">            tempimg = images[i].ravel()</code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;">            tempimg = images[i].ravel()</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">            nx, ny = images[i].shape</code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;">            nx, ny = images[i].shape</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">            # generate the coordinate axes</code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;">            # generate the coordinate axes</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">            x, y = np.mgrid[:nx, :ny]</code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;">            x, y = np.mgrid[:nx, :ny]</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;"></code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">            initial_guess = (0.5, offsets[i][0], offsets[i][1], 2., 2., 0)</code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;">            initial_guess = (0.5, offsets[i][0], offsets[i][1], 2., 2., 0)</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">            # do the fit</code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;">            # do the fit</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">            popt, pcov = opt.curve_fit(twoD_Gaussian, (x,y), tempimg, p0=initial_guess,</code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;">            popt, pcov = opt.curve_fit(twoD_Gaussian, (x,y), tempimg, p0=initial_guess,</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">                                       bounds=([0, 0, 0, 0, 0, 0], [1., nx, ny, nx, ny, 6.28]))</code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;">                                       bounds=([0, 0, 0, 0, 0, 0], [1., nx, ny, nx, ny, 6.28]))</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">            amp, x, y, dx, dy, theta = popt</code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;">            amp, x, y, dx, dy, theta = popt</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">            x += centers[i][0] - offsets[i][0]</code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;">            x += centers[i][0] - offsets[i][0]</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">            y += centers[i][1] - offsets[i][1]</code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;">            y += centers[i][1] - offsets[i][1]</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">            fit_params = fit_params.append({'Amplitude': amp,</code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;">            fit_params = fit_params.append({'Amplitude': amp,</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">                                            'Xo': x,</code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;">                                            'Xo': x,</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">                                            'Yo': y,</code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;">                                            'Yo': y,</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">                                            'sigmaX': dx,</code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;">                                            'sigmaX': dx,</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">                                            'sigmaY': dy,</code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;">                                            'sigmaY': dy,</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">                                            'theta': theta}, ignore_index=True)</code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;">                                            'theta': theta}, ignore_index=True)</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;"></code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">        except Exception as ex:</code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;">        except Exception as ex:</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">            pass</code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;">            pass</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;"></code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">    return fit_params</code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;">    return fit_params</code></td></tr>
#     </table>
#
# ### make_cutouts()
# <table style="margin-left:0px;">
#         <tr><td style="text-align:left;"><code style="background-color: #c8cbce;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c6f7d3;">@python_app(executors=['local_tpex'])</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">def make_cutouts(in_img: np.ndarray, peaks: list, radius: int = 10) -> tuple:</code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;">def make_cutouts(in_img: np.ndarray, peaks: list, radius: int = 10) -> tuple:</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c6f7d3;">    import numpy as np</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">    img = in_img.astype(np.float32)/255.</code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;">    img = in_img.astype(np.float32)/255.</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">    images = []</code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;">    images = []</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">    centers = []</code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;">    centers = []</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">    offsets = []</code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;">    offsets = []</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">    for peak in peaks:</code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;">    for peak in peaks:</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">        # initialize the boundaries</code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;">        # initialize the boundaries</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">        xmin = img.shape[0]</code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;">        xmin = img.shape[0]</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">        ymin = img.shape[1]</code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;">        ymin = img.shape[1]</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">        xmax = 0</code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;">        xmax = 0</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">        ymax = 0</code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;">        ymax = 0</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">        xmedian = 0</code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;">        xmedian = 0</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">        ymedian = 0</code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;">        ymedian = 0</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;"></code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">        # loop through each set of coordinates and adjust the bounds to contain them all</code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;">        # loop through each set of coordinates and adjust the bounds to contain them all</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">        for c in peak:</code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;">        for c in peak:</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">            xmedian += c[0]</code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;">            xmedian += c[0]</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">            ymedian += c[1]</code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;">            ymedian += c[1]</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">            xmin = min(c[0], xmin)</code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;">            xmin = min(c[0], xmin)</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">            ymin = min(c[1], ymin)</code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;">            ymin = min(c[1], ymin)</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">            xmax = max(c[0], xmax)</code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;">            xmax = max(c[0], xmax)</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">            ymax = max(c[1], ymax)</code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;">            ymax = max(c[1], ymax)</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">        # add a small buffer space</code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;">        # add a small buffer space</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">        xmin = int(max(xmin - radius, 0))</code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;">        xmin = int(max(xmin - radius, 0))</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">        ymin = int(max(ymin - radius, 0))</code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;">        ymin = int(max(ymin - radius, 0))</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">        xmax = int(min(xmax + radius + 1, img.shape[0]))</code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;">        xmax = int(min(xmax + radius + 1, img.shape[0]))</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">        ymax = int(min(ymax + radius + 1, img.shape[1]))</code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;">        ymax = int(min(ymax + radius + 1, img.shape[1]))</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;"></code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">        # cut out the sub image</code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;">        # cut out the sub image</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">        images.append(img[xmin:xmax, ymin:ymax])</code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;">        images.append(img[xmin:xmax, ymin:ymax])</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">        center = (xmedian / len(peak), ymedian / len(peak))</code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;">        center = (xmedian / len(peak), ymedian / len(peak))</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">        centers.append(center)</code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;">        centers.append(center)</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">        offsets.append((center[0] - xmin, center[1] - ymin))</code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;">        offsets.append((center[0] - xmin, center[1] - ymin))</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">    return images, centers, offsets</code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;">    return images, centers, offsets</code></td></tr>
#
# </table>
#
# ### make_image()
# <table style="margin-left:0px;">
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c6f7d3;">@python_app(executors=['local_tpex'])</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f7e9a8;">def make_image(in_img: np.ndarray, fit: list, label: str) -> None:</code></td>
#         <td style="text-align:left;"><code style="background-color: #f7e9a8;">def make_image(in_img: np.ndarray, fit: pd.DataFrame, label: str, outputs: list = []) -> None:</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c6f7d3;">    import numpy as np</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c6f7d3;">    import matplotlib.pyplot as mpl</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c6f7d3;">    from mpl_toolkits.axes_grid1 import make_axes_locatable</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c6f7d3;">    from parsl.data_provider.files import File</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c6f7d3;"></code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c6f7d3;">    def twoD_Gaussian(point: tuple, amplitude: float, xo: float, yo: float, sigma_x: float, sigma_y: float,</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c6f7d3;">                      theta: float):</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c6f7d3;">        (x, y) = point</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c6f7d3;">        xo = float(xo)</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c6f7d3;">        yo = float(yo)</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c6f7d3;">        a = (np.cos(theta) ** 2) / (2 * sigma_x ** 2) + (np.sin(theta) ** 2) / (2 * sigma_y ** 2)</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c6f7d3;">        b = -(np.sin(2 * theta)) / (4 * sigma_x ** 2) + (np.sin(2 * theta)) / (4 * sigma_y ** 2)</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c6f7d3;">        c = (np.sin(theta) ** 2) / (2 * sigma_x ** 2) + (np.cos(theta) ** 2) / (2 * sigma_y ** 2)</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c6f7d3;">        gaussian = amplitude * np.exp(-(a * ((x - xo) ** 2) + 2 * b * (x - xo) * (y - yo) + c * ((y - yo) ** 2)))</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c6f7d3;">        return gaussian.ravel()</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;"></code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">    img = in_img.astype(np.float32)/255.</code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;">    img = in_img.astype(np.float32)/255.</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">    model = img.copy()</code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;">    model = img.copy()</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">    model.fill(0.)</code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;">    model.fill(0.)</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">    x, y = np.mgrid[:img.shape[0], :img.shape[1]]</code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;">    x, y = np.mgrid[:img.shape[0], :img.shape[1]]</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">    fit = fit.reset_index()</code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;">    fit = fit.reset_index()</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">    for i, p in fit.iterrows():</code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;">    for i, p in fit.iterrows():</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">        model += twoD_Gaussian((x, y), p['Amplitude'], p['Xo'], p['Yo'], p['sigmaX'],</code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;">        model += twoD_Gaussian((x, y), p['Amplitude'], p['Xo'], p['Yo'], p['sigmaX'],</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">                               p['sigmaY'], p['theta']).reshape(img.shape[0], img.shape[1])</code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;">                               p['sigmaY'], p['theta']).reshape(img.shape[0], img.shape[1])</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;"></code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">    f, axs = mpl.subplots(1, 2, sharey=True)</code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;">    f, axs = mpl.subplots(1, 2, sharey=True)</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">    f.set_figwidth(14)</code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;">    f.set_figwidth(14)</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">    f.set_figheight(6)</code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;">    f.set_figheight(6)</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">    axs[0].imshow(img, vmin=0., vmax=1.)</code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;">    axs[0].imshow(img, vmin=0., vmax=1.)</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">    p = axs[1].imshow(img-model, vmin=0., vmax=1.)</code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;">    p = axs[1].imshow(img-model, vmin=0., vmax=1.)</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">    d = make_axes_locatable(axs[1])</code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;">    d = make_axes_locatable(axs[1])</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">    cx = d.append_axes("right", size="10%", pad="2%")</code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;">    cx = d.append_axes("right", size="10%", pad="2%")</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">    mpl.colorbar(p, cax=cx)</code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;">    mpl.colorbar(p, cax=cx)</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">    f.suptitle("Band: " + label)</code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;">    f.suptitle("Band: " + label)</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c6f7d3;">    mpl.savefig(outputs[0].filepath, format='png')</code></td></tr>
#
# </table>
#
# ### make_catalog()
# <table style="margin-left:0px;">
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c6f7d3;">@python_app(executors=['local_tpex'])</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f7e9a8;">def make_catalog(tables, labels):</code></td>
#         <td style="text-align:left;"><code style="background-color: #f7e9a8;">def make_catalog(tables, labels, outputs=[]):</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c6f7d3;">    from astropy.io import fits</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c6f7d3;">    from parsl.data_provider.files import File</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c6f7d3;"></code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">    hdus = [fits.PrimaryHDU()]</code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;">    hdus = [fits.PrimaryHDU()]</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">    counts = {}</code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;">    counts = {}</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">    for i, v in enumerate(tables):</code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;">    for i, v in enumerate(tables):</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">        counts[labels[i]] = v['Amplitude'].values.shape[0]</code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;">        counts[labels[i]] = v['Amplitude'].values.shape[0]</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">        col1 = fits.Column(name='Amp', format='E', array=v['Amplitude'].values)</code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;">        col1 = fits.Column(name='Amp', format='E', array=v['Amplitude'].values)</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">        col2 = fits.Column(name='Xo', format='E', array=v['Xo'].values)</code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;">        col2 = fits.Column(name='Xo', format='E', array=v['Xo'].values)</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">        col3 = fits.Column(name='Yo', format='E', array=v['Yo'].values)</code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;">        col3 = fits.Column(name='Yo', format='E', array=v['Yo'].values)</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">        col4 = fits.Column(name='sigmaX', format='E', array=v['sigmaX'].values)</code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;">        col4 = fits.Column(name='sigmaX', format='E', array=v['sigmaX'].values)</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">        col5 = fits.Column(name='sigmaY', format='E', array=v['sigmaY'].values)</code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;">        col5 = fits.Column(name='sigmaY', format='E', array=v['sigmaY'].values)</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">        col6 = fits.Column(name='theta', format='E', array=v['theta'].values)</code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;">        col6 = fits.Column(name='theta', format='E', array=v['theta'].values)</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;"></code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">        hdu = fits.BinTableHDU.from_columns([col1, col2, col3, col4, col5, col6])</code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;">        hdu = fits.BinTableHDU.from_columns([col1, col2, col3, col4, col5, col6])</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">        hdu.header['band'] = labels[i]</code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;">        hdu.header['band'] = labels[i]</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">        hdus.append(hdu)</code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;">        hdus.append(hdu)</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">    hdul = fits.HDUList(hdus)</code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;">    hdul = fits.HDUList(hdus)</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f7e9a8;">    hdul.writeto('parameters.fits', overwrite=True)</code></td>
#         <td style="text-align:left;"><code style="background-color: #f7e9a8;">    hdul.writeto(outputs[0].filepath, overwrite=True)</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">    print("Found these object counts")</code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;">    print("Found these object counts")</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">    for i, v in counts.items():</code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;">    for i, v in counts.items():</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">        print(f"{i}: {v}")</code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;">        print(f"{i}: {v}")</code></td></tr>
#
# </table>
#
# ### main
# <table style="margin-left:0px;">
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">lbls = ["red", "green", "blue"]</code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;">lbls = ["red", "green", "blue"]</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;">params = []</code></td>
#         <td style="text-align:left;"><code style="background-color: #f5f5f5;">params = []</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c6f7d3;">image = File(os.path.join(os.getcwd(), "noao-m34.png"))</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c6f7d3;">si = split_image(inputs=[image])</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c6f7d3;"></code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c6f7d3;">fts = []</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c6f7d3;">made_images = []</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f7e9a8;">for i, im in enumerate(split_image("noao-m34.png")):</code></td>
#         <td style="text-align:left;"><code style="background-color: #f7e9a8;">for i, im in enumerate(si.result()):</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;">    pks = find_peaks(im)</code></td>
#         <td style="text-align:left;"><code style="background-color: #c8cbce;">    pks = find_peaks(im)</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f7e9a8;">    images, centers, offsets = make_cutouts(im, pks)</code></td>
#         <td style="text-align:left;"><code style="background-color: #f7e9a8;">    mc = make_cutouts(im, pks.result())</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f7e9a8;">    fit = make_fits(images, centers, offsets)</code></td>
#         <td style="text-align:left;"><code style="background-color: #f7e9a8;">    fts.append(make_fits(mc.result()))</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f7e9a8;">    params.append(fit)</code></td>
#         <td style="text-align:left;"><code style="background-color: #f7e9a8;"></code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f7e9a8;">    make_image(img, fit, lbls[i])</code></td>
#         <td style="text-align:left;"><code style="background-color: #f7e9a8;">    made_images.append(make_image(im, fts[i].result(), lbls[i], outputs=[File(os.path.join(os.getcwd(), lbls[i] + "_compare.png"))]))</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c6f7d3;"></code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c6f7d3;">for ft in fts:</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c6f7d3;">    params.append(ft.result())</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c6f7d3;"></code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c6f7d3;">for mi in made_images:</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #c8cbce;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c6f7d3;">    mi.result()</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c6f7d3;"></code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f7e9a8;">make_catalog(params, lbls)</code></td>
#         <td style="text-align:left;"><code style="background-color: #f7e9a8;">mkcat = make_catalog(params, lbls, outputs=[File(os.path.join(os.getcwd(), 'parameters.fits'))])</code></td></tr>
#     <tr><td style="text-align:left;"><code style="background-color: #f5f5f5;"></code></td>
#         <td style="text-align:left;"><code style="background-color: #c6f7d3;">mkcat.result()</code></td></tr>
#
# </table>
